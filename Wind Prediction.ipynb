# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('wind_dataset.csv', parse_dates=True)
#index_col=['DATE']

# %%
data
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0     1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1     1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2     1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3     1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4     1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 6569  1978-12-27  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0
# 6570  1978-12-28  14.33    0  16.0    0.0    9.1    0.0    8.5      8.0
# 6571  1978-12-29  19.17    0  14.7    0.0    5.0    0.0    3.5      3.2
# 6572  1978-12-30  18.08    0   4.9    0.0    2.9    0.0    0.3     -0.5
# 6573  1978-12-31  19.25    0   0.5    0.0    1.2    1.0   -1.5     -3.0
#
# [6574 rows x 9 columns]

# %%
data['YEAR'] = pd.DatetimeIndex(data['DATE']).year
data['MONTH'] = pd.DatetimeIndex(data['DATE']).month
data['DAY'] = pd.DatetimeIndex(data['DATE']).day

# %%
data.dtypes
# Out:
# DATE        object
# WIND       float64
# IND          int64
# RAIN       float64
# IND.1      float64
# T.MAX      float64
# IND.2      float64
# T.MIN      float64
# T.MIN.G    float64
# YEAR         int64
# MONTH        int64
# DAY          int64
# dtype: object

# %%
data.head()
# Out:
#          DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G  YEAR  \
# 0  1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0  1961
# 1  1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1  1961
# 2  1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5  1961
# 3  1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2  1961
# 4  1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5  1961
#
#    MONTH  DAY
# 0      1    1
# 1      1    2
# 2      1    3
# 3      1    4
# 4      1    5

# %%
sns.pairplot(data=data)

# %%
data.dtypes
# Out:
# DATE        object
# WIND       float64
# IND          int64
# RAIN       float64
# IND.1      float64
# T.MAX      float64
# IND.2      float64
# T.MIN      float64
# T.MIN.G    float64
# YEAR         int64
# MONTH        int64
# DAY          int64
# dtype: object

# %%
data.corr()
# Out:
#              WIND       IND      RAIN     IND.1     T.MAX     IND.2     T.MIN  \
# WIND     1.000000 -0.038578  0.120876  0.070512 -0.242559  0.047860 -0.093014
# IND     -0.038578  1.000000 -0.148535 -0.028176 -0.075365 -0.015173 -0.050447
# RAIN     0.120876 -0.148535  1.000000  0.023944 -0.044248  0.012567  0.011067
# IND.1    0.070512 -0.028176  0.023944  1.000000 -0.036045  0.909739 -0.033344
# T.MAX   -0.242559 -0.075365 -0.044248 -0.036045  1.000000 -0.247060  0.789980
# IND.2    0.047860 -0.015173  0.012567  0.909739 -0.247060  1.000000 -0.535746
# T.MIN   -0.093014 -0.050447  0.011067 -0.033344  0.789980 -0.535746  1.000000
# T.MIN.G  0.012823 -0.064185  0.027365 -0.004040  0.679804 -0.129421  0.906869
# YEAR    -0.069690  0.189814 -0.008446 -0.321999 -0.005192 -0.292556  0.052259
# MONTH   -0.066635  0.017213  0.038679  0.031042  0.223176  0.008129  0.212065
# DAY      0.000502 -0.001591 -0.008988 -0.000179  0.005987 -0.008422  0.011160
#
#           T.MIN.G      YEAR     MONTH       DAY
# WIND     0.012823 -0.069690 -0.066635  0.000502
# IND     -0.064185  0.189814  0.017213 -0.001591
# RAIN     0.027365 -0.008446  0.038679 -0.008988
# IND.1   -0.004040 -0.321999  0.031042 -0.000179
# T.MAX    0.679804 -0.005192  0.223176  0.005987
# IND.2   -0.129421 -0.292556  0.008129 -0.008422
# T.MIN    0.906869  0.052259  0.212065  0.011160
# T.MIN.G  1.000000 -0.061966  0.175768  0.004933
# YEAR    -0.061966  1.000000 -0.000077  0.000088
# MONTH    0.175768 -0.000077  1.000000  0.010674
# DAY      0.004933  0.000088  0.010674  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data = data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data.isna().sum()
# Out:
# DATE       0
# WIND       0
# IND        0
# RAIN       0
# IND.1      0
# T.MAX      0
# IND.2      0
# T.MIN      0
# T.MIN.G    0
# dtype: int64

# %%
#data['T.MAX'].fillna(data['T.MAX'].median(), inplace =True)

# %%
data['T.MAX'].isna().sum()
# Out:
# 621

# %%
data['T.MAX'].interpolate(inplace=True)

# %%
data.fillna(0, inplace=True)
data.isnull().sum().sum()
# Out:
# 0

# %%
data.drop('DATE', axis =1, inplace = True)

# %%
data.columns
# Out:
# Index(['DATE', 'WIND', 'IND', 'RAIN', 'IND.1', 'T.MAX', 'IND.2', 'T.MIN',
#        'T.MIN.G', 'YEAR', 'MONTH', 'DAY'],
#       dtype='object')

# %%
X = data.drop('WIND', axis =1)
y = data['WIND']

# %%
X
# Out:
#       IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G  YEAR  MONTH  DAY
# 0       0   0.2    0.0    9.5    0.0    3.7     -1.0  1961      1    1
# 1       0   5.1    0.0    7.2    0.0    4.2      1.1  1961      1    2
# 2       0   0.4    0.0    5.5    0.0    0.5     -0.5  1961      1    3
# 3       0   0.2    0.0    5.6    0.0    0.4     -3.2  1961      1    4
# 4       0  10.4    0.0    7.2    1.0   -1.5     -7.5  1961      1    5
# ...   ...   ...    ...    ...    ...    ...      ...   ...    ...  ...
# 6569    0  16.8    0.0    9.8    0.0    4.0      0.0  1978     12   27
# 6570    0  16.0    0.0    9.1    0.0    8.5      8.0  1978     12   28
# 6571    0  14.7    0.0    5.0    0.0    3.5      3.2  1978     12   29
# 6572    0   4.9    0.0    2.9    0.0    0.3     -0.5  1978     12   30
# 6573    0   0.5    0.0    1.2    1.0   -1.5     -3.0  1978     12   31
#
# [6574 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size =.2, random_state =42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
y_true = y_test

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_true, y_pred)
# Out:
# 19.09314927148289

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_true, y_pred)
# Out:
# 0.23851970592731964
